# %%
import numpy as np
import pandas as pd

# %%
# loading the dataset to pandas dataframe
diabetes_data = pd.read_csv('./data/diabetes.csv')

# %%
# learn about particular function use '?' symbol example below
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'list[HashableT] | Callable[[Hashable], bool] | None' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Sequence[str] | Mapping[str, Sequence[str]] | None' = None,
# ...

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# getting statistical measures of data
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### Legends
# * 0 -> Non-Diabetic
# * 1 -> Diabetic

# %%
diabetes_data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# printing the correlation heatmap using seaborn
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(diabetes_data.corr(),cmap='YlGnBu',annot=True,fmt='.1f')
plt.show()

# %%
diabetes_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# seprating the data and labels
X = diabetes_data.drop(columns=['Outcome'],axis=1)
y = diabetes_data['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ### Data Strandardisation

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_data = scaler.fit_transform(X)
y_data = y.to_numpy()

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_data, y_data, test_size=0.2, stratify=y_data, random_state=2)

# %%
X_data.shape, X_train.shape, X_test.shape
# Out:
# ((768, 8), (614, 8), (154, 8))

# %%
# running the ML algo using support vector machine
from sklearn import svm

clf = svm.SVC(kernel='linear')

# %%
# training the support vector machine classifier

clf.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score

# accuracy score on training data
X_train_prediction = clf.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,y_train)

# %%
training_data_accuracy
# Out:
# 0.7866449511400652

# %%
X_test_prediction = clf.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction,y_test)

# %%
print(f'Accuracy score of the test data: {testing_data_accuracy}')
# Out:
# Accuracy score of the test data: 0.7727272727272727

# %%
# saving trained model in pickle file
import pickle

with open('./model/model.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %%
# loading the model from pickle file
with open('./model/model.pkl','rb') as f:
    loaded_clf = pickle.load(f)

# %% [markdown]
# ### Making a Predictive System

# %%
input_data = (1,89,66,23,94,28.1,0.167,21)

# change input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input daata
std_data = scaler.transform(input_data_reshaped)

prediction = loaded_clf.predict(std_data)

if prediction[0]:
    print(f'The paitent is diabetic')
else:
    print(f'The person is diabetic')
# Out:
# The person is diabetic
# /home/coral/Downloads/Python/diabetes_prediction/venv/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
